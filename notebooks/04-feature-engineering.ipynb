# %% [markdown]
# # Feature Engineering
#
# Merging topic shares, sentiment, and external data (e.g., IPI).

# %%
import pandas as pd

def create_features(monthly_topic_shares_by_publisher_path: str, features_path: str):
    # Load data
    topics = pd.read_csv(monthly_topic_shares_by_publisher_path)
    sentiment = pd.read_csv("../data/processed/monthly_sentiment_all.csv")
    ipi = pd.read_csv("../data/raw/INDPRO.csv")

    # Ensure date formats match
    topics['month'] = pd.to_datetime(topics['month'].astype(str))
    sentiment['month'] = pd.to_datetime(sentiment['date'].astype(str))
    ipi['month'] = pd.to_datetime(ipi['observation_date'].astype(str))

    # For topic data
    topics['month'] = pd.to_datetime(topics['month']).dt.to_period('M').dt.to_timestamp()

    # For sentiment data
    sentiment['month'] = pd.to_datetime(sentiment['date']).dt.to_period('M').dt.to_timestamp()

    # Merge on month + publication
    df = topics.merge(sentiment, on=['month', 'publication'], how='left')
    df = df.merge(ipi, on='month', how='left')

    # Drop rows with missing target (INDPRO)
    df = df.dropna(subset=['INDPRO'])

    # One-hot encode publisher
    df = pd.get_dummies(df, columns=['publication'], drop_first=True)

    # print preview of the final DataFrame
    cols = ['month', 'INDPRO', 'sentiment'] + [c for c in df.columns if c not in ('month', 'INDPRO', 'sentiment')]
    display(df[cols].head())

    # save features to csv
    df.to_csv(features_path, index=False)

# %% [markdown]
# LDA Features

# %%
create_features(
    monthly_topic_shares_by_publisher_path="../data/processed/monthly_topic_shares_by_publisher.csv",
    features_path="../data/processed/features_lda_monthly.csv"
)
# Out:
#        month   INDPRO  sentiment   topic_0   topic_1   topic_2   topic_3  \
# 0 2016-01-01  99.4391  -0.332366  0.047303  0.108757  0.065400  0.177487
# 1 2016-01-01  99.4391  -0.359760  0.048579  0.034060  0.039285  0.080410
# 2 2016-01-01  99.4391  -0.453634  0.076843  0.100812  0.062806  0.020819
# 3 2016-01-01  99.4391  -0.449364  0.178754  0.065679  0.069355  0.092416
# 4 2016-01-01  99.4391  -0.171123  0.027663  0.115164  0.163197  0.309055
#
#     topic_4   topic_5   topic_6  ...  publication_TMZ  publication_TechCrunch  \
# 0  0.078956  0.089427  0.147791  ...            False                   False
# 1  0.048981  0.047445  0.082206  ...            False                   False
# 2  0.084967  0.164064  0.143699  ...            False                   False
# 3  0.028589  0.146400  0.133294  ...            False                   False
# 4  0.035086  0.034965  0.189210  ...            False                   False
#
#    publication_The Hill publication_The New York Times publication_The Verge  \
# 0                 False                          False                 False
# 1                 False                          False                 False
# 2                 False                          False                 False
# 3                 False                          False                 False
# 4                 False                          False                 False
#
#    publication_Vice  publication_Vice News  publication_Vox  \
# 0             False                  False            False
# 1             False                  False            False
# 2             False                  False            False
# 3             False                  False            False
# 4             False                  False            False
#
#    publication_Washington Post  publication_Wired
# 0                        False              False
# 1                        False              False
# 2                        False              False
# 3                        False              False
# 4                        False              False
#
# [5 rows x 40 columns]

# %% [markdown]
# BERTopic Features

# %%
create_features(
    monthly_topic_shares_by_publisher_path="../data/processed/monthly_topic_shares_by_publisher_bertopic.csv",
    features_path="../data/processed/features_bertopic_monthly.csv"
)
# Out:
#        month   INDPRO  sentiment   topic_0   topic_1   topic_2   topic_3  \
# 0 2016-01-01  99.4391  -0.332366  0.096154  0.192308  0.153846  0.019231
# 1 2016-01-01  99.4391  -0.359760  0.016807  0.042017  0.134454  0.050420
# 2 2016-01-01  99.4391  -0.453634  0.100000  0.050000  0.016667  0.411111
# 3 2016-01-01  99.4391  -0.449364  0.061674  0.154185  0.074890  0.061674
# 4 2016-01-01  99.4391  -0.171123  0.036145  0.328313  0.307229  0.006024
#
#     topic_4   topic_5   topic_6  ...  publication_TMZ  publication_TechCrunch  \
# 0  0.134615  0.250000  0.000000  ...            False                   False
# 1  0.058824  0.588235  0.008403  ...            False                   False
# 2  0.266667  0.027778  0.016667  ...            False                   False
# 3  0.273128  0.189427  0.008811  ...            False                   False
# 4  0.015060  0.021084  0.000000  ...            False                   False
#
#    publication_The Hill publication_The New York Times publication_The Verge  \
# 0                 False                          False                 False
# 1                 False                          False                 False
# 2                 False                          False                 False
# 3                 False                          False                 False
# 4                 False                          False                 False
#
#    publication_Vice  publication_Vice News  publication_Vox  \
# 0             False                  False            False
# 1             False                  False            False
# 2             False                  False            False
# 3             False                  False            False
# 4             False                  False            False
#
#    publication_Washington Post  publication_Wired
# 0                        False              False
# 1                        False              False
# 2                        False              False
# 3                        False              False
# 4                        False              False
#
# [5 rows x 40 columns]

# %% [markdown]
# sLDA Features

# %%
create_features(
    monthly_topic_shares_by_publisher_path="../data/processed/monthly_topic_shares_by_publisher_sLDA.csv",
    features_path="../data/processed/features_slda_monthly.csv"
)
# Out:
#        month   INDPRO  sentiment   topic_0   topic_1   topic_2   topic_3  \
# 0 2016-01-01  99.4391  -0.332366  0.113924  0.096957  0.073923  0.136457
# 1 2016-01-01  99.4391  -0.359760  0.057679  0.044100  0.071563  0.061600
# 2 2016-01-01  99.4391  -0.453634  0.135860  0.049119  0.155220  0.033329
# 3 2016-01-01  99.4391  -0.449364  0.035915  0.062259  0.288431  0.050607
# 4 2016-01-01  99.4391  -0.171123  0.074303  0.018143  0.032679  0.324294
#
#     topic_4   topic_5   topic_6  ...  publication_TMZ  publication_TechCrunch  \
# 0  0.097931  0.152317  0.141147  ...            False                   False
# 1  0.053359  0.114329  0.438747  ...            False                   False
# 2  0.082012  0.049961  0.070695  ...            False                   False
# 3  0.053273  0.057251  0.194292  ...            False                   False
# 4  0.211499  0.059117  0.056758  ...            False                   False
#
#    publication_The Hill publication_The New York Times publication_The Verge  \
# 0                 False                          False                 False
# 1                 False                          False                 False
# 2                 False                          False                 False
# 3                 False                          False                 False
# 4                 False                          False                 False
#
#    publication_Vice  publication_Vice News  publication_Vox  \
# 0             False                  False            False
# 1             False                  False            False
# 2             False                  False            False
# 3             False                  False            False
# 4             False                  False            False
#
#    publication_Washington Post  publication_Wired
# 0                        False              False
# 1                        False              False
# 2                        False              False
# 3                        False              False
# 4                        False              False
#
# [5 rows x 40 columns]

# %% [markdown]
# MiniLLM Features

# %%
create_features(
    monthly_topic_shares_by_publisher_path="../data/processed/monthly_topic_shares_by_publisher_minillm.csv",
    features_path="../data/processed/features_minillm_monthly.csv"
)
# Out:
#        month   INDPRO  sentiment   topic_0   topic_1   topic_2   topic_3  \
# 0 2016-01-01  99.4391  -0.359760  0.282868  0.303174  0.055365  0.184831
# 1 2016-01-01  99.4391  -0.453634  0.335409  0.275612  0.085674  0.257200
# 2 2016-01-01  99.4391  -0.449364  0.292521  0.237691  0.103655  0.168196
# 3 2016-01-01  99.4391  -0.171123  0.143012  0.271206  0.045638  0.173059
# 4 2016-01-01  99.4391  -0.297804  0.136806  0.257614  0.011366  0.254939
#
#     topic_4   topic_5   topic_6  ...  publication_Mashable  \
# 0  0.314040  0.278684  0.204099  ...                 False
# 1  0.190609  0.399465  0.330665  ...                 False
# 2  0.191956  0.222145  0.195695  ...                 False
# 3  0.269370  0.137411  0.142544  ...                 False
# 4  0.203234  0.128820  0.170342  ...                 False
#
#    publication_New Republic  publication_New Yorker publication_Politico  \
# 0                     False                   False                False
# 1                     False                   False                False
# 2                     False                   False                False
# 3                     False                   False                False
# 4                     False                   False                False
#
#   publication_Reuters  publication_The Hill  publication_The Verge  \
# 0               False                 False                  False
# 1               False                 False                  False
# 2               False                 False                  False
# 3               False                 False                  False
# 4               False                 False                  False
#
#    publication_Vice News  publication_Washington Post  publication_Wired
# 0                  False                        False              False
# 1                  False                        False              False
# 2                  False                        False              False
# 3                  False                        False              False
# 4                  False                        False              False
#
# [5 rows x 32 columns]

# %% [markdown]
# LLM Features

# %%
create_features(
    monthly_topic_shares_by_publisher_path="../data/processed/monthly_topic_shares_by_publisher_llm.csv",
    features_path="../data/processed/features_llm_monthly.csv"
)
